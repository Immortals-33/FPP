# %%
# Run this cell to render a mitosheet
# See mito's documentation here: https://docs.trymito.io/how-to/creating-a-mitosheet
# Join our Discord for support here: https://discord.com/invite/XdJSZyejJU

import mitosheet
mitosheet.sheet(analysis_to_replay="id-aouktsvsrk")
# Out:
# <div id=e8e45945-6743-48d5-8fda-ef2e74f014e7 class="mito-container-container">
#         <script>
# ...

# %%
from mitosheet.public.v3 import *; register_analysis("id-aouktsvsrk");
import pandas as pd

# Imported 设计指标.csv
设计指标 = pd.read_csv(r'C:\\Users\\dell\\Desktop\\Papers\\设计指标.csv', encoding='GB2312')

# Filtered 序列恢复率
设计指标 = 设计指标[设计指标['序列恢复率'] > 0.5]
